# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key
import gmaps.datasets

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/WeatherPy_vacation.csv")
city_data_df
# Out:
#      City_ID  City_ID.1           City Country                 Date    Lat  \
# 0          0          0      Palembang      ID  2020-02-24 02:57:22  -2.92
# 1          1          1      Hurricane      US  2020-02-24 02:57:23  37.18
# 2          2          2          Pisco      PE  2020-02-24 02:57:23 -13.70
# 3          3          3         Faanui      PF  2020-02-24 02:57:23 -16.48
# 4          4          4        College      US  2020-02-24 02:57:24  64.86
# ..       ...        ...            ...     ...                  ...    ...
# 553      553        553  Kahramanmaras      TR  2020-02-24 03:02:22  38.00
# 554      554        554       Karasjok      NO  2020-02-24 03:02:23  69.47
# 555      555        555        Malindi      KE  2020-02-24 03:02:23  -3.22
# 556      556        556           Ende      ID  2020-02-24 03:02:24  -8.84
# 557      557        557     Borogontsy      RU  2020-02-24 03:02:25  62.67
#
#         Lng  Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 0    104.75     85.21        69           3        6.73          light rain
# 1   -113.29     51.80        75           0        6.93           clear sky
# 2    -76.22     77.00        78          75        8.05       broken clouds
# 3   -151.75     83.39        70           6        9.04          light rain
# 4   -147.80     -2.00        70          20        0.87          few clouds
# ..      ...       ...       ...         ...         ...                 ...
# 553   37.00     44.60        93          75        5.82                mist
# 554   25.51     33.80        80         100       31.09     overcast clouds
# 555   40.12     80.60        88          40        2.24    scattered clouds
# 556  121.66     83.80        70          52        4.50       broken clouds
# 557  131.17     -0.89        93          93        3.96     overcast clouds
#
#      Rain Inches (last 3 hrs)  Snow Inches (last 3 hrs)
# 0                        0.50                       0.0
# 1                        0.00                       0.0
# 2                        0.00                       0.0
# 3                        0.13                       0.0
# 4                        0.00                       0.0
# ..                        ...                       ...
# 553                      0.00                       0.0
# 554                      0.00                       0.0
# 555                      0.00                       0.0
# 556                      0.00                       0.0
# 557                      0.00                       0.0
#
# [558 rows x 14 columns]

# %%
ulladulla_city_au = city_data_df[(city_data_df["City"] == "Ulladulla")]
ulladulla_city_au
# Out:
#      City_ID  City_ID.1       City Country                 Date    Lat  \
# 244      244        244  Ulladulla      AU  2020-02-24 02:59:52 -35.35
#
#         Lng  Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 244  150.47      84.2        39           0       10.29           clear sky
#
#      Rain Inches (last 3 hrs)  Snow Inches (last 3 hrs)
# 244                       0.0                       0.0

# %%
flinders_city_au = city_data_df[(city_data_df["City"] == "Flinders")]
flinders_city_au
# Out:
#      City_ID  City_ID.1      City Country                 Date    Lat     Lng  \
# 370      370        370  Flinders      AU  2020-02-24 03:00:55 -34.58  150.86
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 370      84.2        39           0       10.29           clear sky
#
#      Rain Inches (last 3 hrs)  Snow Inches (last 3 hrs)
# 370                       0.0                       0.0

# %%
lithgow_city_au = city_data_df[(city_data_df["City"] == "Lithgow")]
lithgow_city_au
# Out:
#      City_ID  City_ID.1     City Country                 Date    Lat     Lng  \
# 268      268        268  Lithgow      AU  2020-02-24 03:00:04 -33.48  150.15
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 268      84.0        57          90        8.05     overcast clouds
#
#      Rain Inches (last 3 hrs)  Snow Inches (last 3 hrs)
# 268                       0.0                       0.0

# %%
moree_city_au = city_data_df[(city_data_df["City"] == "Moree")]
moree_city_au
# Out:
#     City_ID  City_ID.1   City Country                 Date    Lat     Lng  \
# 56       56         56  Moree      AU  2020-02-24 02:58:25 -29.47  149.85
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 56      78.8        61          90        2.24     overcast clouds
#
#     Rain Inches (last 3 hrs)  Snow Inches (last 3 hrs)
# 56                       0.0                       0.0

# %%
moree_city_coord = (moree_city_au["Lat"], moree_city_au["Lng"])
moree_city_coord
# Out:
# (56   -29.47
#  Name: Lat, dtype: float64,
#  56    149.85
#  Name: Lng, dtype: float64)

# %%
lithgow_city_coord = (lithgow_city_au["Lat"], lithgow_city_au["Lng"])
lithgow_city_coord
# Out:
# (268   -33.48
#  Name: Lat, dtype: float64,
#  268    150.15
#  Name: Lng, dtype: float64)

# %%
flinders_city_coord = (flinders_city_au["Lat"], flinders_city_au["Lng"])
flinders_city_coord
# Out:
# (370   -34.58
#  Name: Lat, dtype: float64,
#  370    150.86
#  Name: Lng, dtype: float64)

# %%
ulladulla_city_coord = (ulladulla_city_au["Lat"], ulladulla_city_au["Lng"])
ulladulla_city_coord
# Out:
# (244   -35.35
#  Name: Lat, dtype: float64,
#  244    150.47
#  Name: Lng, dtype: float64)

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
fig = gmaps.figure()
ulladulla2moree_via_flinders_lithgow = gmaps.directions_layer(
        ulladulla_city_coord, moree_city_coord,waypoints=[flinders_city_coord,lithgow_city_coord],
        travel_mode='DRIVING')
fig.add_layer(ulladulla2moree_via_flinders_lithgow)
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-2a0cd52ec558> in <module>
#       2 ulladulla2moree_via_flinders_lithgow = gmaps.directions_layer(
#       3         ulladulla_city_coord, moree_city_coord,waypoints=[flinders_city_coord,lithgow_city_coord],
# ----> 4         travel_mode='DRIVING')
#       5 fig.add_layer(ulladulla2moree_via_flinders_lithgow)
#       6 fig
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\gmaps\directions.py in directions_layer(start, end, waypoints, avoid_ferries, travel_mode, avoid_highways, avoid_tolls, optimize_waypoints, show_markers, show_route, stroke_color, stroke_weight, stroke_opacity)
#     280         'stroke_opacity': stroke_opacity
#     281     }
# --> 282     return Directions(**kwargs)
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\gmaps\directions.py in __init__(self, start, end, waypoints, **kwargs)
#     205                 waypoints = []
#     206             kwargs.update(dict(start=start, end=end, waypoints=waypoints))
# --> 207         super(Directions, self).__init__(**kwargs)
#     208
#     209     @staticmethod
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in __init__(self, *args, **kwargs)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
# -> 1000                     super_kwargs[key] = value
#    1001         try:
#    1002             super(HasTraits, self).__init__(*super_args, **super_kwargs)
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\gmaps\directions.py in _calc_bounds(self, change)
#     233     def _calc_bounds(self, change):
#     234         all_data = [self.start] + self.waypoints + [self.end]
# --> 235         min_latitude = min(row[0] for row in all_data)
#     236         min_longitude = min(row[1] for row in all_data)
#     237         max_latitude = max(row[0] for row in all_data)
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     519
#     520         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 521             raise ValueError("Can only compare identically-labeled Series objects")
#     522
#     523         lvalues = extract_array(self, extract_numpy=True)
#
# ValueError: Can only compare identically-labeled Series objects
